# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t').set_index('order_id')

# %%
chipo
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['search_price'] = chipo.item_price.map(lambda p: p[1:]).astype('float')
new_chipo = chipo.drop_duplicates(subset=['item_name', 'quantity'])
new_chipo.loc[(new_chipo.quantity == 1) & (new_chipo.search_price > 10)].groupby('item_name').min().shape
# Out:
# (12, 4)

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
new_chipo.loc[:, ['item_name', 'item_price']]
new_chipo.loc[(new_chipo.quantity == 1), ['item_name', 'search_price']].groupby('item_name').min().sort_values(by='search_price', ascending=False)
# Out:
#                                        search_price
# item_name
# Carnitas Salad Bowl                           11.89
# Barbacoa Salad Bowl                           11.89
# Steak Salad Bowl                              11.89
# Steak Burrito                                 11.75
# Barbacoa Crispy Tacos                         11.75
# Barbacoa Bowl                                 11.75
# Veggie Soft Tacos                             11.25
# Veggie Salad Bowl                             11.25
# Veggie Bowl                                   11.25
# Veggie Burrito                                11.25
# Chicken Salad                                 10.98
# Chicken Bowl                                  10.98
# Steak Crispy Tacos                             9.25
# Steak Soft Tacos                               9.25
# Carnitas Soft Tacos                            9.25
# Carnitas Crispy Tacos                          9.25
# Barbacoa Soft Tacos                            9.25
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name', ascending=True)
# Out:
#           quantity          item_name  \
# order_id
# 1360             2  6 Pack Soft Drink
# 148              1  6 Pack Soft Drink
# 749              1  6 Pack Soft Drink
# 754              1  6 Pack Soft Drink
# 1076             1  6 Pack Soft Drink
# ...            ...                ...
# 948              1  Veggie Soft Tacos
# 322              1  Veggie Soft Tacos
# 1132             1  Veggie Soft Tacos
# 688              1  Veggie Soft Tacos
# 567              1  Veggie Soft Tacos
#
#                                          choice_description item_price  \
# order_id
# 1360                                            [Diet Coke]    $12.98
# 148                                             [Diet Coke]     $6.49
# 749                                                  [Coke]     $6.49
# 754                                             [Diet Coke]     $6.49
# 1076                                                 [Coke]     $6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by='search_price', ascending=False).head(1)
# Out:
#           quantity                     item_name choice_description  \
# order_id
# 1443            15  Chips and Fresh Tomato Salsa                NaN
#
#          item_price  search_price
# order_id
# 1443        $44.25          44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo.loc[chipo.item_name == 'Veggie Salad Bowl'].quantity.sum()
# Out:
# np.int64(18)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo.loc[(chipo.item_name == 'Canned Soda') & (chipo.quantity > 1)].order_id.co
# Out:
#           quantity    item_name choice_description item_price  search_price
# order_id
# 9                2  Canned Soda           [Sprite]     $2.18           2.18
# 23               2  Canned Soda     [Mountain Dew]     $2.18           2.18
# 73               2  Canned Soda        [Diet Coke]     $2.18           2.18
# 76               2  Canned Soda  [Diet Dr. Pepper]     $2.18           2.18
# 150              2  Canned Soda        [Diet Coke]     $2.18           2.18
# 151              2  Canned Soda        [Coca Cola]     $2.18           2.18
# 287              2  Canned Soda        [Coca Cola]     $2.18           2.18
# 288              2  Canned Soda        [Coca Cola]     $2.18           2.18
# 376              2  Canned Soda     [Mountain Dew]     $2.18           2.18
# 450              2  Canned Soda       [Dr. Pepper]     $2.18           2.18
# 450              2  Canned Soda        [Coca Cola]     $2.18           2.18
# ...
